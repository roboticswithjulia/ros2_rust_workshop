# %% [markdown]
# <p align="center">
#   <img src="./ros_developers_day/images/ROSConSpain.jpeg" width="500" title="ROS Developers Day">
# </p>

# %% [markdown]
# <p align="center">
#   <img src="./ros_developers_day/images/ROS2 Rust.png" width="800" title="ROS2 RUST logo">
# </p>

# %% [markdown]
# <div>
#     <h1 class="text-center">
#         <span class="text-primary">Workshop | Tutorial</span>
#         &nbsp;
#         <span class="">Desarrollo de Aplicaciones Reales en Robótica con ROS2 y Rust</span>
#     </h1>
# </div>

# %% [markdown]
# Rust es un lenguaje que permite crear un software confiable y eficiente. ROS2, el marco de trabajo para sistemas operativos robóticos, ahora ofrece la posibilidad de ser utilizado con Rust. Con este proyecto, aprenderás a desarrollar nodos en Rust para tus aplicaciones robóticas reales.
#
# En este workshop, aprenderás lo siguiente:
#
# * [1. ¿Qué es / Por qué Rust?](#whatisrust)
# * [2. Cómo instalar Rust con ROS2](#howtoinstallrust)
# * [3. Cómo mover un robot con ROS2 y Rust](#movearobotwithROS2)
# * [3.1 Cómo crear un paquete de ROS en Rust](#createarustrospackage)
# * [3.2 Consejos básicos de programación en Rust](#basicrustprogrammingtips)
# * [3.3 Cómo crear un *subscriber* en Rust](#howtocreateasubscribertoscantopicinrust)
# * [3.4 Cómo crear un *publisher* en Rust](#howtocreateapublishertocmdvelinrust)
# * [3.5 Cómo crear un *subscriber* y un *publisher* en el mismo nodo.](#howtocreatasubandpub)
# * [4. Trabajo futuro](#futurework)
# * [5. Preguntas y respuestas](#QandA)

# %% [markdown]
# <div>
#     <h1 class="text-center">
#         <span class="text-primary"></span>
#         &nbsp;
#         <span class="">Me presento:</span>
#     </h1>
# </div>

# %% [markdown]
# Mi nombre es Júlia Marsal, y soy Ingeniera Industrial con un Máster en Robótica. Comencé en el campo de la robótica cuando tenía 16 años, y hasta ahora he trabajado en diferentes universidades y empresas desarrollando aplicaciones de Software de robótica a medida.

# %% [markdown]
# <p align="center">
#     <img src="./ros_developers_day/images/JMrobotics.png" width="200" align="center">
# </p>

# %% [markdown]
# Soy Consultora en Ingeniería Robótica, y actualmente desarrollo software para dte, una empresa de robótica localizada en Islandia, la cual produce aplicaciones robóticas para los metales del futuro.
# Además, ayudo a estudiantes impartiendo cursos de robótica para diferentes universidades y empresas bajo demanda, lo cual me fascina.

# %% [markdown]
# <p align="center">
#     <img src="./ros_developers_day/images/dte.png" width="150"  align="center">
# </p>

# %% [markdown]
# No dudes en contactarme si hay algo más en lo que pueda asistirte.

# %% [markdown]
# <p align="center">
#   <img src="./ros_developers_day/images/LinkedIn Julia.jpg" width="350" title="julia linkedin">
# </p>

# %% [markdown]
#  <a name="whatisrust"></a>
# <div>
#     <h1 class="text-center">
#         <span class="text-primary">1.</span>
#         &nbsp;
#         <span class="">¿Qué es / Por qué Rust?</span>
#     </h1>
# </div>

# %% [markdown]
# Rust es un lenguaje de programación de sistemas diseñado para el rendimiento, la seguridad y la concurrencia. Fue desarrollado originalmente por Mozilla y ahora es mantenido por la Fundación Rust, que incluye partes de código abierto.

# %% [markdown]
# <p align="center">
#   <img src="./ros_developers_day/images/Rust_Foundation_logo.png" width="200" title="The Rust Foundation">
# </p>

# %% [markdown]
# Aquí tienes algunas características y aspectos clave de Rust:

# %% [markdown]
# <p align="center">
#   <img src="./ros_developers_day/images/Rust_diagram.png" width="800" title="Rust diagram">
# </p>

# %% [markdown]
# <a name="howtoinstallrust"></a>
# <div>
#     <h1 class="text-center">
#         <span class="text-primary">2.</span>
#         &nbsp;
#         <span class="">Cómo instalar Rust con ROS2</span>
#     </h1>
# </div>

# %% [markdown]
# Los paquetes de ROS2 no se pueden ubicar como bindings dentro de los paquetes de Rust; la única forma de hacerlo actualmente es instalar desde el código fuente o mediante un Dockerfile. Puedes encontrar estos recursos en:
# https://github.com/ros2-rust/ros2_rust.

# %% [markdown]
# <a name="movearobotwithROS2"></a>
# <div>
#     <h1 class="text-center">
#         <span class="text-primary">3.</span>
#         &nbsp;
#         <span class="">Cómo mover un robot con ROS2 y Rust</span>
#     </h1>
# </div>

# %% [markdown]
# <a name="createarustrospackage"></a>
# <div>
#     <h2 class="text-center">
#         <span class="text-primary">3.1</span>
#         &nbsp;
#         <span class="">Cómo crear un paquete de ROS en Rust</span>
#     </h2>
# </div>

# %% [markdown]
# **Cargo** es el gestor de paquetes y herramienta de construcción para Rust. Facilita la gestión de dependencias, la construcción de proyectos y la ejecución de pruebas. A través de Cargo, puedes compilar tu código, descargar y actualizar paquetes de terceros (llamados "crates"), y administrar configuraciones de tu proyecto.
#
# **Crates** es el nombre que se utiliza para referirse a los paquetes de Rust. Un crate es una unidad de código distribuible que puede ser una biblioteca o un ejecutable. Los crates se gestionan a través de Cargo, el gestor de paquetes de Rust, que facilita su publicación, instalación y actualización. [Crates.io website](https://crates.io/).
#
# Existen dos tipos principales de crates:
#
# - **Crates de biblioteca**: Contienen código que puede ser utilizado por otros crates. No tienen un punto de entrada principal.
# - **Crates binarios**: Contienen un punto de entrada principal (main), que puede ser ejecutado como un programa independiente.
#
# Los crates se definen en el archivo *Cargo.toml*, donde se especifican sus dependencias y configuraciones.

# %% [markdown]
# <p align="center">
#   <img src="./ros_developers_day/images/rclrs crates.png" width="700" title="julia linkedin">
# </p>

# %%
cargo new <pkg_name>

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Ejecuta en la terminal #1
# </span>

# %%
cd /workspaces/src
cargo new rust_apps

# %% [markdown]
# Cada paquete de Cargo en ROS2 tendrá la siguiente estructura de archivos y carpetas:
#
# - Carpeta `src`: Contiene los archivos fuente (Rust, CPP, Python).
# - `Cargo.toml`: Archivo donde puedes definir las dependencias (crates), metadatos y algunas configuraciones del compilador.
# - `Cargo.lock`: Contiene información exacta sobre tus dependencias. Es mantenido por Cargo y no debe ser editado manualmente.
#
# Son esenciales, así que recuerda lo siguiente:
#
# - Cada programa ROS2 que quieras ejecutar está organizado en un paquete.
# - Cada programa ROS2 que crees debe estar organizado en un paquete.
# - Los paquetes son el sistema principal de organización para los programas de ROS2.

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Ejecuta en la Terminal #1
# </span>

# %%
cd /workspaces/src/rust_apps
tree -c

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#    Terminal #1 output
# </span>

# %% [markdown]
# <pre style="color: white; background: black; padding:10px; font: 1.3rem Inconsolata, monospace;">
# .
# |-- Cargo.toml
# `-- src
#     `-- main.rs
#
# 1 directory, 2 files
# </pre>

# %% [markdown]
# Para que ROS reconozca que se trata de un paquete ROS, es necesario agregar un archivo package.xml. Este archivo contiene la información de metadatos sobre el paquete, como su nombre, versión, autor, y las dependencias necesarias.

# %% [markdown]
# Para crear un archivo package.xml dentro del directorio rust_pkg y copiar el código proporcionado, sigue estos pasos:

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Code editor: rust_apps/package.xml
# </span>

# %%
<package format="3">
  <name>rust_apps</name>
  <version>0.0.0</version>
  <description>ROS2 Rust main package</description>
  <maintainer email="user@gmail.com">user</maintainer>
  <license>MIT</license>

  <depend>rclrs</depend>

  <export>
    <build_type>ament_cargo</build_type>
  </export>
</package>

# %% [markdown]
# Los principales atajos de Rust:
#
# - `cargo build`
# - `cargo run`
# - `cargo install <name of the package>`

# %% [markdown]
# No vamos a usar estos comandos en absoluto ya que estamos usando ROS2, así que utilizaremos comandos de ROS2.

# %% [markdown]
# Para proyectos grandes, es posible que no desees compilar todos los paquetes de inmediato. En su lugar, puedes seguir los siguientes enfoques:

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Ejecuta en la Terminal #1
# </span>

# %%
cd /workspaces

# %%
colcon build --packages-select rust_apps

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#    Salida de la Terminal #1
# </span>

# %% [markdown]
# <pre style="color: white; background: black; padding:10px; font: 1.3rem Inconsolata, monospace;">
# Starting >>> rust_apps
# Finished <<< rust_apps [10.0s]
#
# Summary: 1 package finished [10.2s]
# </pre>

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Ejecuta en la Terminal #1
# </span>

# %%
source install/setup.sh

# %% [markdown]
# Ahora tenemos el *crate* (paquete ROS2) listo para implementar un nodo ROS2 utilizando Rust.

# %% [markdown]
# <a name="basicrustprogrammingtips"></a>
# <div>
#     <h2 class="text-center">
#         <span class="text-primary">3.2</span>
#         &nbsp;
#         <span class="">Consejos Básicos de Programación en Rust</span>
#     </h2>
# </div>

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.2.1</span>
#         &nbsp;
#         <span class="">Funciones</span>
#     </h3>
# </div>

# %%
fn <function_name>(variable:type){} -> <return_type>

# %%
fn main() -> Result<(), Error> {}

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.2.2</span>
#         &nbsp;
#         <span class="">Mutabilidad</span>
#     </h3>
# </div>

# %% [markdown]
# Para crear una nueva variable y asignarle un valor, se utiliza **let**. Si la variable es mutable (es decir, su valor puede cambiar), se debe utilizar **mut**.

# %%
let mut message = std_msgs::msg::String::default();

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.2.3</span>
#         &nbsp;
#         <span class="">Pasos para Crear un Nodo de ROS2 en Rust</span>
#     </h3>
# </div>

# %% [markdown]
# <div>
#     <h4 class="text-center">
#         <span class="text-primary">3.2.3.1</span>
#         &nbsp;
#         <span class="">Crea el contexto, el estado compartido entre nodos y entidades similares.</span>
#     </h4>
# </div>

# %%
let context = rclrs::Context::new(env::args())?;

# %% [markdown]
# <div>
#     <h4 class="text-center">
#         <span class="text-primary">3.2.3.2</span>
#         &nbsp;
#         <span class="">Crear el nodo.</span>
#     </h4>
# </div>

# %%
pub fn create_node(
    context: &Context,
    node_name: &str
) -> Result<Arc<Node>, RclrsError>

# %%
let node = rclrs::create_node(&context, "<node_name>")?;

# %% [markdown]
# <div>
#     <h4 class="text-center">
#         <span class="text-primary">3.2.3.3</span>
#         &nbsp;
#         <span class="">Crear un subscriber.</span>
#     </h4>
# </div>

# %%
source
pub fn create_subscription<T, Args>(
    &self,
    topic: &str,
    qos: QoSProfile,
    callback: impl SubscriptionCallback<T, Args>
) -> Result<Arc<Subscription<T>>, RclrsError>
where
    T: Message,

# %%
let _subscription = node.create_subscription::<sensor_msgs::msg::LaserScan, _>(
    "scan",
    rclrs::QOS_PROFILE_DEFAULT,
    move |msg: sensor_msgs::msg::LaserScan| {
        println!("Angle min: '{}'", msg.angle_min);
    },
)?;

# %% [markdown]
# <div>
#     <h4 class="text-center">
#         <span class="text-primary">3.2.3.4</span>
#         &nbsp;
#         <span class="">Crear un publisher.</span>
#     </h4>
# </div>

# %%
pub fn create_publisher<T>(
    &self,
    topic: &str,
    qos: QoSProfile
) -> Result<Arc<Publisher<T>>, RclrsError>
where
    T: Message,

# %%
let publisher = node.create_publisher::<Twist>("cmd_vel", rclrs::QOS_PROFILE_DEFAULT)?;
publisher.publish(&cmd_vel_message)?;

# %% [markdown]
# <div>
#     <h4 class="text-center">
#         <span class="text-primary">3.2.3.5</span>
#         &nbsp;
#         <span class="">Qué QoSProfile (Perfil de Calidad de Servicio) tenemos implementado?.</span>
#     </h4>
# </div>

# %% [markdown]
# - QOS_PROFILE_CLOCK
# - QOS_PROFILE_DEFAULT
# - QOS_PROFILE_PARAMETERS
# - QOS_PROFILE_PARAMETER_EVENTS
# - QOS_PROFILE_SENSOR_DATA
# - QOS_PROFILE_SERVICES_DEFAULT
# - QOS_PROFILE_SYSTEM_DEFAULT

# %% [markdown]
# Dado que el tema del QoS (Quality of Service) es complejo y está fuera del alcance de la sesión de aprendizaje actual, utilizaremos el perfil de QoS predeterminado, QOS_PROFILE_DEFAULT. Si deseas aprender más sobre QoS y cómo personalizarlo para tus necesidades específicas, te recomiendo que consultes la página oficial de ROS2 [QoS](https://docs.ros.org/en/rolling/Concepts/Intermediate/About-Quality-of-Service-Settings.html).

# %% [markdown]
# <div>
#     <h4 class="text-center">
#         <span class="text-primary">3.2.3.6</span>
#         &nbsp;
#         <span class="">ROS spin - usar fuera de un bucle.</span>
#     </h4>
# </div>

# %% [markdown]
# pub fn spin(node: Arc<Node>) -> Result<(), RclrsError>

# %%
rclrs::spin(node).map_err(|err| err.into())

# %% [markdown]
# <div>
#     <h4 class="text-center">
#         <span class="text-primary">3.2.3.7</span>
#         &nbsp;
#         <span class="">ROS spin_once - usar dentro de un bucle.</span>
#     </h4>
# </div>

# %%
pub fn spin_once(
    node: Arc<Node>,
    timeout: Option<Duration>
) -> Result<(), RclrsError>

# %%
rclrs::spin_once(node.clone(), Some(std::time::Duration::from_millis(500)));

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.2.4</span>
#         &nbsp;
#         <span class="">Creación y uso de estructuras y métodos</span>
#     </h3>
# </div>

# %%
struct Rectangle {
    width: u32,
    height: u32,
}

impl Rectangle {
    fn area(&self) -> u32 {
        self.width * self.height
    }
}

# %% [markdown]
# <a name="howtocreateasubscribertoscantopicinrust"></a>
# <div>
#     <h2 class="text-center">
#         <span class="text-primary">3.3</span>
#         &nbsp;
#         <span class="">How to create a Rust scan Subscriber</span>
#     </h2>
# </div>

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.3.1</span>
#         &nbsp;
#         <span class="">Code implementation</span>
#     </h3>
# </div>

# %% [markdown]
# Rename the file **main.rs -> subscriber.rs**.

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
cd ~/ros2_ws/src/wandering_behavior_rust/src

# %%
mv main.rs scan_subscriber.rs

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Code editor: wandering_behavior_rust/src/scan_subscriber.rs
# </span>

# %%
use std::env;
use anyhow::{Error, Result};

fn main() -> Result<(), Error> {
    let context = rclrs::Context::new(env::args())?;

    let node = rclrs::create_node(&context, "scan_subscriber")?;

    let mut num_messages: usize = 0;

    let _subscription = node.create_subscription::<sensor_msgs::msg::LaserScan, _>(
        "scan",
        rclrs::QOS_PROFILE_DEFAULT,
        move |msg: sensor_msgs::msg::LaserScan| {
            num_messages += 1;
            println!("Mid range[m]: '{}'", msg.ranges[msg.ranges.len()/2]);
            println!("Angle min: '{}'", msg.angle_min);
            println!("Angle max: '{}'", msg.angle_max);
            println!("(Got {} messages so far)", num_messages);
        },
    )?;

    rclrs::spin(node).map_err(|err| err.into())
}

# %% [markdown]
# Add the ROS2 dependencies manually: Add **sensor_msgs** inside the **package.xml**.

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Code editor: wandering_behavior_rust/package.xml
# </span>

# %%
  <depend>sensor_msgs</depend>

# %% [markdown]
# Add dependencies with other crates and also link the file with a the ROS2 node in  ~/wandering_behavior_rust/src/rust_pkg/cargo.toml.

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Code editor: wandering_behavior_rust/cargo.toml
# </span>

# %%
[dependencies.sensor_msgs]
sensor_msgs = "*"

# %%
[[bin]]
name = "scan_subscriber_node"
path = "src/scan_subscriber.rs"

# %% [markdown]
# Add the dependencies automatically:

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
cargo add anyhow
cargo add rclrs

# %% [markdown]
# Build the node:

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
cd ~/ros2_ws

# %%
colcon build --packages-select wandering_behavior_rust

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.3.2</span>
#         &nbsp;
#         <span class="">Code execution</span>
#     </h3>
# </div>

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
cd ~/ros2_ws

# %%
source install/setup.sh

# %%
ros2 run wandering_behavior_rust scan_subscriber_node

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#    Terminal #1 output
# </span>

# %% [markdown]
# <pre style="color: white; background: black; padding:10px; font: 1.3rem Inconsolata, monospace;">
# Mid angle: '0.61015296'
# Angle min: '0'
# Angle max: '6.28'
# (Got 1 messages so far)
# Mid angle: '0.58275497'
# Angle min: '0'
# Angle max: '6.28'
# (Got 2 messages so far)
# Mid angle: '0.59380335'
# Angle min: '0'
# Angle max: '6.28'
# (Got 3 messages so far)
# Mid angle: '0.5930826'
# Angle min: '0'
# Angle max: '6.28'
# (Got 4 messages so far)
# </pre>

# %% [markdown]
# <a name="howtocreateapublishertocmdvelinrust"></a>
# <div>
#     <h2 class="text-center">
#         <span class="text-primary">3.4</span>
#         &nbsp;
#         <span class="">How to create a Rust cmd_vel Publisher</span>
#     </h2>
# </div>

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.4.1</span>
#         &nbsp;
#         <span class="">Code implementation</span>
#     </h3>
# </div>

# %% [markdown]
# Create a new file inside rust_pkg named *cmd_vel_publisher.rs* and paste the following code:

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Code editor: wandering_behavior_rust/src/cmd_vel_publisher.rs
# </span>

# %%
use std::env;
use anyhow::{Error, Result};
use geometry_msgs::msg::Twist as Twist;

fn main() -> Result<(), Error> {
    let context = rclrs::Context::new(env::args())?;

    let node = rclrs::create_node(&context, "cmd_vel_publisher")?; 

    let publisher = node.create_publisher::<Twist>("cmd_vel", rclrs::QOS_PROFILE_DEFAULT)?;

    let mut cmd_vel_message = Twist::default();

    let mut velocity = 0.2;

    while context.ok() {
        cmd_vel_message.linear.x = velocity;
        cmd_vel_message.angular.z = velocity;
        if velocity < -0.2 {velocity = 0.2}
        else {velocity-=0.05};
        println!("Moving velocity lineal x: {} and angular z: {} m/s.",cmd_vel_message.linear.x , cmd_vel_message.angular.z);
        publisher.publish(&cmd_vel_message)?;
        std::thread::sleep(std::time::Duration::from_millis(500));
    }
    Ok(())
}

# %% [markdown]
# Add the dependency *geometry_msgs* and add the new node named cmd_vel_publisher inside the Cargo.toml

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Code editor: wandering_behavior_rust/Cargo.toml
# </span>

# %%
[dependencies.geometry_msgs]
geometry_msgs = "*"

# %%
[[bin]]
name = "cmd_vel_publisher_node"
path = "src/cmd_vel_publisher.rs"

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Code editor: wandering_behavior_rust/package.xml
# </span>

# %%
  <depend>geometry_msgs</depend>

# %% [markdown]
# Build the ROS2 package:

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
cd ~/ros2_ws

# %%
colcon build --packages-select wandering_behavior_rust

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.4.2</span>
#         &nbsp;
#         <span class="">Code execution</span>
#     </h3>
# </div>

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
cd ~/ros2_ws

# %%
source install/setup.sh

# %% [markdown]
# Open *gazebo* window and search for the turtlebot3 robot and then execute the cmd_vel_publisher node.

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
ros2 run wandering_behavior_rust cmd_vel_publisher_node

# %% [markdown]
# <div class="bg-danger text-center">
#     - Expected Result -
# </div>

# %% [markdown]
# <img src="./ros_developers_day/videos/publisher_gif.gif" width="800" height="800" />

# %% [markdown]
# <div class="bg-danger text-center">
#     - End Expected Result -
# </div>

# %% [markdown]
# <a name="howtocreatasubandpub"></a>
# <div>
#     <h2 class="text-center">
#         <span class="text-primary">3.5</span>
#         &nbsp;
#         <span class="">How to create a Subscriber and Publisher at the same Node</span>
#     </h2>
# </div>

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.5.1</span>
#         &nbsp;
#         <span class="">Code implementation</span>
#     </h3>
# </div>

# %% [markdown]
# Real projects extend beyond simple publisher and subscriber models. Let's collaborate to create a Rust struct that encompasses both a publisher and a subscriber. This struct will enable the robot to autonomously navigate the simulation environment, avoiding collisions independently.

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Code editor: wandering_behavior_rust/src/obstacle_avoidance.rs
# </span>

# %%
use std::{
    env,
    sync::{
        Arc, Mutex,
    },
};
use sensor_msgs::msg::LaserScan as LaserScan;
use geometry_msgs::msg::Twist as Twist;
use anyhow::{Error, Result};

struct ObstacleAvoidance {
    _subscription:Arc<rclrs::Subscription<LaserScan>>,
    publication: Arc<rclrs::Publisher<Twist>>,
    twist_msg:  Arc<Mutex<Twist>>
}

impl ObstacleAvoidance {
    pub fn new(node: &rclrs::Node) -> Result<Self, rclrs::RclrsError> {
        let twist_msg = Arc::new(Mutex::new(Twist::default()));
        let publication = node.create_publisher::<Twist>("cmd_vel", rclrs::QOS_PROFILE_DEFAULT)?;
        let twist_msg_clone = Arc::clone(&twist_msg);
        let _subscription = node.create_subscription::<LaserScan, _>(
            "scan",
            rclrs::QOS_PROFILE_DEFAULT,
            move |msg: LaserScan| {
                let mut twist_msg = twist_msg_clone.lock().unwrap();
                let current_distance_front = msg.ranges[0];
                let current_distance_left = msg.ranges[msg.ranges.len() / 4];
                let current_distance_back = msg.ranges[msg.ranges.len() / 2];
                let current_distance_right = msg.ranges[3*msg.ranges.len() / 4];

                println!("distance [m]: front '{:?}', right '{:?}', back '{:?}', left '{:?}'", 
                current_distance_front, current_distance_right, current_distance_back, current_distance_left);
                if current_distance_front < 0.5 
                {
                    twist_msg.linear.x = -0.1;
                    twist_msg.angular.z = 0.15;
                }
                else if current_distance_right < 0.5 
                {
                    twist_msg.linear.x = 0.1;
                    twist_msg.angular.z = 0.15;
                }
                else if current_distance_back < 0.5
                {
                    twist_msg.linear.x = 0.1;
                    twist_msg.angular.z = 0.15;
                }
                else if current_distance_left < 0.5
                {
                    twist_msg.linear.x = 0.1;
                    twist_msg.angular.z = -0.15;
                } 
                
                else {
                    twist_msg.linear.x = 0.15;
                }
            },
            )?;


        Ok(Self{
            _subscription,
            publication,
            twist_msg,
        })
    }

    pub fn publish(&self) 
    {
      let twist_msg = self.twist_msg.lock().unwrap();
      let _ = self.publication.publish(&*twist_msg);
    }
}

fn main() -> Result<(), Error> {
    let context = rclrs::Context::new(env::args())?;
    let node = rclrs::create_node(&context, "minimal_subscriber_one")?;
    let subscriber_node_one = ObstacleAvoidance::new(&node)?;
    while context.ok() {
        subscriber_node_one.publish();
        let _ = rclrs::spin_once(node.clone(), Some(std::time::Duration::from_millis(500)));
        std::thread::sleep(std::time::Duration::from_millis(500));
    }
    Ok(())

}

# %% [markdown]
# Add the new node executable in the Cargo.toml

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Code editor: wandering_behavior_rust/Cargo.toml
# </span>

# %%
[[bin]]
name = "obstacle_avoidance_node"
path = "src/obstacle_avoidance.rs"

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
cd ~/ros2_ws

# %%
colcon build --packages-select wandering_behavior_rust

# %%
source install/setup.sh

# %% [markdown]
# <div>
#     <h3 class="text-center">
#         <span class="text-primary">3.5.2</span>
#         &nbsp;
#         <span class="">Code execution</span>
#     </h3>
# </div>

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
ros2 run wandering_behavior_rust obstacle_avoidance_node

# %% [markdown]
# <div class="bg-danger text-center">
#     - Expected Result -
# </div>

# %% [markdown]
# <img src="./ros_developers_day/videos/obstacle_avoidance.gif" width="900" height="900" />

# %% [markdown]
# <div class="bg-danger text-center">
#     - End Expected Result -
# </div>

# %% [markdown]
# If you want to stop the robot after executing from the terminal with **CTRL+C**:

# %% [markdown]
# <span class="badge badge-pill badge-primary">
#     <i class="fa fa-play"></i>
#     &nbsp;
#     Execute in Terminal #1
# </span>

# %%
ros2 topic pub --once /cmd_vel geometry_msgs/msg/Twist '{linear: {x: 0.0, y: 0.0, z: 0.0}, angular: {x: 0.0, y: 0.0, z: 0.0}}'

# %% [markdown]
# <a name="futurework"></a>
# <div>
#     <h2 class="text-center">
#         <span class="text-primary">4.</span>
#         &nbsp;
#         <span class="">Future work</span>
#     </h2>
# </div>

# %% [markdown]
# You are now prepared to build nodes in Rust. To further enhance your proficiency, I recommend reviewing the following courses and documentation

# %% [markdown]
# - https://doc.rust-lang.org/book/
# - https://github.com/ros2-rust/ros2_rust
# - [ROS2 Basics in 3 Days (Rust)](https://app.theconstruct.ai/courses/168)
# - [ROS2 Developers open class](https://youtu.be/ShCnUasOBzU?feature=shared)

# %% [markdown]
# <a name="QandA"></a>
# <div>
#     <h2 class="text-center">
#         <span class="text-primary">5.</span>
#         &nbsp;
#         <span class="">Q&A</span>
#     </h2>
# </div>

# %% [markdown]
# <p align="center">
#   <img src="./ros_developers_day/images/thankyou.png" width="500" title="thank you">
# </p>

# %% [markdown]
# <p align="center">
#   <img src="./ros_developers_day/images/theconstructlogo.png" width="400" title="the construct logo">
# </p>
